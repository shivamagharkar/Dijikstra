# %%
import pandas as pd

# %%
df=pd.read_csv('cleaned_data_set.csv')
df
# Out:
#        age     workclass educational level  years of studying  \
# 0       25       Private              11th                  7
# 1       38       Private           HS-grad                  9
# 2       28     Local-gov        Assoc-acdm                 12
# 3       44       Private      Some-college                 10
# 4       18       Unknown      Some-college                 10
# ...    ...           ...               ...                ...
# 48837   27       Private        Assoc-acdm                 12
# 48838   40       Private           HS-grad                  9
# 48839   58       Private           HS-grad                  9
# 48840   22       Private           HS-grad                  9
# 48841   52  Self-emp-inc           HS-grad                  9
#
#            marital status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
df1 = pd.get_dummies(df, columns=['workclass', 'educational level', 'marital status', 'occupation', 'relationship', 'race', 'gender', 'country of origin'])

# %%
X = df1.drop('income', axis=1)
y = df['income']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=103)
model = LogisticRegression(max_iter=10000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)
print(f"Accuracy: {accuracy}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Classification Report:\n{classification_rep}")
# Out:
# Accuracy: 0.8360118742962432
# Confusion Matrix:
# [[6833  584]
#  [1018 1334]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90      7417
#            1       0.70      0.57      0.62      2352
#
#     accuracy                           0.84      9769
#    macro avg       0.78      0.74      0.76      9769
# weighted avg       0.83      0.84      0.83      9769

# %%
class_pred = model.predict(X)
prob_pred = model.predict_proba(X)
pd.DataFrame({'Income status (1=50K and above , 0=Under 50k)' : class_pred, 
              'Probability of 50K and above': prob_pred[:,1],
              'Probability of Under 50k': prob_pred[:,0]
             } 
            )
# Out:
#        Income status (1=50K and above , 0=Under 50k)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
# ...                                              ...
# 48837                                              1
# 48838                                              0
# 48839                                              0
# 48840                                              0
# 48841                                              1
#
#        Probability of 50K and above  Probability of Under 50k
# 0                          0.003648                  0.996352
# 1                          0.163250                  0.836750
# 2                          0.401091                  0.598909
# 3                          0.278526                  0.721474
# ...
